# %%
## Please make sure "project.py" is in your "lab4" folder.
## We will use the same API for both the lab and the project
import project

# %% [markdown]
# ## Segment 2: Learning the API
# ### Task 2.1: Examine the `pokemon_stats` CSV file
# Open `pokemon_stats.csv` with Microsoft Excel or any other spreadsheet software first, and take a look at it. Read the description below the image (of csv file), to understand the statistics related to each Pokémon.
#
# <div>
# <img src="attachment:pokemon_stats.png" width="600"/>
# </div>

# %% [markdown]
# Each Pokémon comes from a certain 'Region', and has one or two 'Types'. A Pokémon with only one Type has 'None' as its value for 'Type 2'. Moreover, each Pokémon has six other statistics, namely:
#
# 1. Attack (short for Physical Attack)
# 2. Defense (short for Physical Defense)
# 3. HP (short for Hit Points)
# 4. Sp. Atk (short for Special Attack)
# 5. Sp. Def (short for Special Defense)
# 6. Speed (which is self explanatory)

# %% [markdown]
# ### Task 2.2: Examine the `type_effectiveness_stats` CSV file
# Next, open `type_effectiveness_stats.csv` with Microsoft Excel or any other Spreadsheet software, and take a look at it. You will see a table of Pokémon types representing the effectiveness of one type against another. The rows represent the type of the defender, and columns represent the type of attacker. Read the description below the image (of csv file), to understand these statistics better.
#
# <div>
# <img src="attachment:type_effectiveness_stats.png" width="900"/>
# </div>

# %% [markdown]
# All Pokémon creatures and their moves are assigned certain types. Each type has several strengths and weaknesses against other Pokémon. In battle, you should use Pokémon and moves that have a type advantage over their opponent; doing so will cause much more damage than otherwise. There are 18 types in this table. Taking the second row (Fire) and the third column (Water) as an example, we see that Water type attack has an effectiveness of 2.0 against Fire type defense.

# %% [markdown]
# ### Task 2.3: Explore the API
#
# `project.py` is designed to give you access to the data in `pokemon_stats.csv` and `type_effectiveness_stats.csv`.
#
# Use the inspection process we learnt in Lab-P3 to learn more details of the 'project' API. In lab-p3, we saw how to use `dir`, and `help` to learn the API.

# %%
## Use the 'dir' function to learn more about the project API and run the cell.
dir(project)

# Next, replace dir with the help function and run the cell again. 
# You should see the details of each function in the project API.

# %% [markdown]
# There are eleven functions here that do not begin with two underscores. Read the documentation or test them out to figure out what they do.

# %%
## You can find the documentation for any function by calling `help` on that function
# Use the help function to read the documentation for the print_stats function.

help(project.???)

# Verify that your result matches the documentation listed in the output of the previous cell.

# %%
#Now try out the print_stats function on the pokemon "Pikachu".
project.???(???)
#Run the cell and verify your output.

# %% [markdown]
# Similarly, try out the functions in each of the cells below.
# Fill in the ??? with sample inputs of your choice. Verify the results against the pokemon_stats.csv file.

# %%
project.get_region('Squirtle')

# %%
project.get_type1(???)

# %%
project.get_type2(???)

# %%
project.get_hp(???)

# %%
project.get_attack(???)

# %%
project.get_defense(???)

# %%
project.get_sp_atk(???)

# %%
project.get_sp_def(???)

# %%
project.get_speed(???)

# %%
project.get_type_effectiveness(???,???)

# %% [markdown]
# ## Segment 3: Conditional Statements
# ### Task 3.1: Explore the `project.get_region` function.

# %%
# Complete the following code that checks if the pokemon 'Pikachu' comes from the region Kanto.
if project.get_region(???) == ???:
    print ('Kanto is the correct region')
else:
    print ('Kanto is not the correct region.')

# %% [markdown]
# What is the output of the above cell? If you change the name of the Pokémon from 'Pikachu' to 'Greninja', does the output change? What happens if you use a bad name (say 'CS220')?

# %% [markdown]
# ### Task 3.2: Explore the `project.get_hp` function.

# %%
# Run the following code
if project.get_hp('Snorlax') >= project.get_hp('Heracross'):
    print('Snorlax')
else:
    print('Heracross')

# %% [markdown]
# ### Task 3.3: Create a `compare_hp` function
# In p4, you will regularly have to compare the stats of different Pokémon.
# So, let's create a useful 'helper' function here. 'Helper functions' can be used by other functions to perform more complicated tasks.

# %%
# The function should return the name of the Pokémon with the higher HP. 
def compare_hp(pkmn1, pkmn2):
    if project.get_hp(???) >= project.get_hp(???):
        return ???
    else:
        return ???

# %%
# Test your function for the Pokémon Snorlax and Heracross
compare_hp('Snorlax', 'Heracross')

# %% [markdown]
# ### Task 3.4: Write a `compare_attack` function
# - this function will return the name of the Pokémon with the higher attack stat.
# - find the function which is used to get the attack statistic of a Pokémon provided in `project.py`.

# %%
def compare_attack(pkmn1, pkmn2):
    #TODO: Return the name of the Pokemon with the higher Attack stat

# %%
# Test your function below.
print("expected: Charmander  actual: ", compare_attack("Bulbasaur", "Charmander") )

# %%
print("expected: Beedrill  actual: ", compare_attack("Beedrill", "Pidgey") )

# %% [markdown]
# ## Segment 4: Advanced Conditional Statements
#
# So far, we have only used if statements to compare two numbers. Let us do something more fancy now. As you might have seen in the `pokemon_stats.csv` file, a Pokémon might have one or more types. For instance, Pikachu has just one type: Electric, whereas Charizard has two: Fire and Flying.
#
# ### Task 4.1: Count how many types a Pokemon has
# Pokémon may have upto two different types associated with them. Let's write a function that returns the number of types a Pokémon has.

# %%
def get_num_types(pkmn):
    if project.get_type1(pkmn) == 'None':
        return 0
    elif project.get_type2(pkmn) == 'None':
        return ???
    else:
        return ???

# %%
# Test the function below
print("expected: 1  actual: ", get_num_types("Kubfu"))

# %%
print("expected: 2  actual: ", get_num_types("Geodude"))

# %% [markdown]
# ### Task 4.2: Determine if two Pokémon have a matching type.
# Let us create a function that checks if two Pokémon have the same types.

# %%
def same_types(pkmn1, pkmn2):
    pkmn1_type1 = project.get_type1(pkmn1)
    pkmn1_type2 = project.get_type2(pkmn1)
    pkmn2_type1 = project.get_type1(pkmn2)
    pkmn2_type2 = project.get_type2(pkmn2)
    
    if pkmn1_type1 == pkmn2_type1:
        if pkmn1_type2 == pkmn2_type2:
            return True
    return False

# %% [markdown]
# ### Task 4.3: Debug your function
#
# There is an error in the function definition above! Run the test code below and determine what the error is.

# %%
#Test your function below
print("Expected: True. Actual: ", same_types('Dragonite', 'Noivern'))

# %% [markdown]
# Use the 'print_stats' function on the two Pokémon above to understand the cause of the error.
# Once identified, modify the function definition to fix the bug. Re-run the above cell to confirm the fix.
#
# **Do not create a new copy of / duplicate the `same_types` function definition.** You should go back to the cell where you previously defined the function, make edits by adding several lines or possibly rewriting the code already there, re-run the function definition cell and then test your function with several calls to it, with different Pokémon.

# %%
project.print_stats(???)

# %%
project.print_stats(???)

# %% [markdown]
# ## Segment 5: Modify Previous functions
# ### Task 5.1: Use Boolean operators to refactor `same_types`
# Now, let's write version 2 for the above function to use logical operators (and / or) to separate different conditions. Modify the code to use logical operators.
#
# Replace the `???` with appropriate operators (and / or). You may need to insert parantheses where required.

# %%
def same_types_v2(pkmn1, pkmn2):
    pkmn1_type1 = project.get_type1(pkmn1)
    pkmn1_type2 = project.get_type2(pkmn1)
    pkmn2_type1 = project.get_type1(pkmn2)
    pkmn2_type2 = project.get_type2(pkmn2)
    
    if pkmn1_type1 == pkmn2_type1 ??? pkmn1_type2 == pkmn2_type2:
        return True
    elif ???:
        return True        
    return False

# %%
# TODO: call same_type and same_type_v2 with same arguments and verify whether your refactoring worked

# %% [markdown]
# ### Task 5.2: Write the function `same_region`
# Write a new function that checks if two Pokémons come from the **same region**.

# %%
def same_region(pkmn1, pkmn2):
    #TODO: Return True if pkmn1 and pkmn2 belong to the same region
    # Return False otherwise
    pass

# %% [markdown]
# ### Task 5.3: Write the function `same_types_and_region`
# Write a new function that checks if two Pokémons are of the same type **and** come from the same region. Make sure to use the functions we created in Task 5.1 and Task 5.2

# %%
def same_types_and_region(pkmn1, pkmn2):
    #TODO: Return True if pkmn1 and pkmn2 are of the same type and belong to the same region
    # Return False in all other cases
    pass

# %%
# Test your function below.
print("Expected: True. Actual: ", same_types_and_region("Bulbasaur", "Ivysaur"))

# %%
print("Expected: False. Actual: ", same_types_and_region("Charmander", "Charizard"))

# %% [markdown]
# ### Task 5.4: Write a function that determines the stronger type
#
# In p4, you will have to compare the strengths of different types against each other. The `get_type_effectiveness` function in `project.py` will be useful for us here. Given two types `type1` and `type2`, we can use that function to find the effectiveness of `type1` against `type2`, and also, the effectiveness of `type2` against `type1`. So, we can compare the effectiveness of the two types against each other, to determine which is stronger.
#
# - Write a function that determines the stronger type out of two.

# %%
def stronger_type(type1, type2):
    type_1_effectiveness = project.get_type_effectiveness(???, ???)
    type_2_effectiveness = ???
    if ??? :
        return type1 + " is stronger than " + type2
    elif ???:
        return type2 + " is stronger than " + type1
    else:
        return type1 + " and " + type2 + " are equally strong"

# %%
#Test your function below
print("Expected: Fire is stronger than Grass. Actual: ", stronger_type("Fire", "Grass"))

# %% [markdown]
# ## Great work! You are now ready to start P4 and become a master Pokémon trainer.
